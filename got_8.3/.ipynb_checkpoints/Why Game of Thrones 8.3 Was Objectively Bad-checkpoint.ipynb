# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# Data from https://www.theatlas.com/charts/HJrdxDNKW
got_data = pd.read_csv('got_data/got_screentime.csv')
got_data.head()
# Out:
#             Character  Minutes
# 0            Jon Snow      338
# 1    Tyrion Lannister      337
# 2  Daenerys Targaryen      276
# 3         Sansa Stark      239
# 4    Cersei Lannister      236

# %%
# Got the 8.3 Cast list from http://time.com/5542922/game-of-thrones-season-8-battle-of-winterfell/
# Checking the data lines up
x = got_data['Character'].values
cast = ['Jon Snow','Daenerys Targaryen','Tyrion Lannister','Sansa Stark','Arya Stark',
       'Bran Stark','Theon Greyjoy','Brienne of Tarth','Jaime Lannister','Podrick Payne',
       'Gendry','Tormund','Davos Seaworth','Melisandre','Grey Worm','Missandei',
       'Eddison Tollett','Samwell Tarly','Gilly','Varys','Jorah Mormont','Lyanna Mormont',
       'Sandor Clegane','Beric Dondarrion','The Night King']
for person in cast:
    if person not in x:
        print(person)

# %%
def is_dead(row):
    if '*' in row['Character']:
        return True
    else:
        return False
    
def is_in_battle_of_winterfell(row):
    cast = ['Jon Snow','Daenerys Targaryen','Tyrion Lannister','Sansa Stark','Arya Stark',
           'Bran Stark','Theon Greyjoy','Brienne of Tarth','Jaime Lannister','Podrick Payne',
           'Gendry','Tormund','Davos Seaworth','Melisandre','Grey Worm','Missandei',
           'Eddison Tollett','Samwell Tarly','Gilly','Varys','Jorah Mormont','Lyanna Mormont',
           'Sandor Clegane','Beric Dondarrion','The Night King']
    if row['Character'] in cast:
        return True
    else:
        return False
    
got_data['Dead'] = got_data.apply (lambda row: is_dead(row), axis=1)
got_data['8.3'] = got_data.apply (lambda row: is_in_battle_of_winterfell(row), axis=1)
got_data.head()
# Out:
#             Character  Minutes   Dead    8.3
# 0            Jon Snow      338  False   True
# 1    Tyrion Lannister      337  False   True
# 2  Daenerys Targaryen      276  False   True
# 3         Sansa Stark      239  False   True
# 4    Cersei Lannister      236  False  False

# %%
dead_people = got_data[got_data.Dead == True]
dead_people.head()
# Out:
#            Character  Minutes  Dead    8.3
# 10    Petyr Baelish*      119  True  False
# 12        Ned Stark*      100  True  False
# 17    Catelyn Stark*       83  True  False
# 18  Tywin Lannister*       78  True  False
# 19  Margaery Tyrell*       78  True  False

# %%
with open('got_data/death_dict.pickle', 'rb') as handle:
    death_dict = pickle.load(handle)

# %%
# Extra death times found from https://www.businessinsider.com/game-of-thrones-everyone-who-has-died-season-7-2017-8
# and https://gameofthrones.fandom.com/wiki/
dead_x = dead_people['Character'].values

def death_episode(row):
    name = row['Character'][:-1]
    try:
        ep = death_dict[name]
    except KeyError:
        # extra dict looked up from Wiki
        # There are 45 episodes up to season 7
        # Most of these are naming conventions or season 7 deaths
        extra_death_dict = {
            'Petyr Baelish':67,
            'Ned Stark': 6,
            'Shireen Baratheon': 49,
            'Barristan Selmy':44,
            'Olenna Tyrell':63, 
            'Talisa': 29,
            'Thoros of Myr':66,
            'Maester Aemon': 47,
            'Benjen Stark': 66,
            'Tyene Sand':63,
            'Randyll Tarly': 65,
            'Qhorin Halfhand': 20,
            'Three-Eyed Raven':55,
            'Nymeria Sand':63,
            'Obara Sand':63,
            'Wun Wun':59,
            'Craster':24,
            'Brother Ray':57,
            'Septa Mordane':8,
            'Spice King':17,
            'Dagmer Cleftjaw':20,
            'Khal Moro':54,
            'Rickard Karstark':25,
            'Rattleshirt':48          
        }
        try:
            ep = extra_death_dict[name]
        except KeyError:
            ep = None
    return(ep)

dead_people['Ep'] = dead_people.apply (lambda row: death_episode(row), axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dead_people['MinPerEp'] = round(dead_people['Minutes']/dead_people['Ep'],3)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dead_people.sort_values('MinPerEp', ascending=False)
# Out:
#                Character  Minutes  Dead    8.3  Ep  MinPerEp
# 12            Ned Stark*      100  True  False   6    16.667
# 126                Will*        6  True  False   1     6.000
# 43     Robert Baratheon*       31  True  False   7     4.429
# 17        Catelyn Stark*       83  True  False  19     4.368
# 20           Robb Stark*       77  True  False  19     4.053
# 64    Viserys Targaryen*       21  True  False   6     3.500
# 23    Joffrey Baratheon*       70  True  False  22     3.182
# 18      Tywin Lannister*       78  True  False  30     2.600
# 53           Khal Drogo*       25  True  False  11     2.273
# 10        Petyr Baelish*      119  True  False  67     1.776
# 29              Ygritte*       51  True  False  29     1.759
# 30                 Shae*       47  True  False  30     1.567
# 63         Jeor Mormont*       21  True  False  14     1.500
# 22    Stannis Baratheon*       73  True  False  50     1.460
# 19      Margaery Tyrell*       78  True  False  60     1.300
# 60                  Ros*       22  True  False  17     1.294
# 124         Jory Cassel*        6  True  False   5     1.200
# 25        Ramsay Bolton*       66  True  False  59     1.119
# 42               Talisa*       31  True  False  29     1.069
# 49       Oberyn Martell*       29  True  False  28     1.036
# 38      Barristan Selmy*       37  True  False  44     0.841
# 127       Septa Mordane*        6  True  False   8     0.750
# 115      Mirri Maz Duur*        8  True  False  11     0.727
# 61                Grenn*       21  True  False  29     0.724
# 34     Tommen Baratheon*       43  True  False  60     0.717
# 33        Olenna Tyrell*       44  True  False  63     0.698
# 58      Renly Baratheon*       24  True  False  35     0.686
# 66           Jojen Reed*       19  True  False  30     0.633
# 37         High Sparrow*       38  True  False  60     0.633
# 71           Lysa Arryn*       17  True  False  27     0.630
# ..                   ...      ...   ...    ...  ..       ...
# 74          Walder Frey*       16  True  False  60     0.267
# 78              Myranda*       13  True  False  50     0.260
# 133     Dagmer Cleftjaw*        5  True  False  20     0.250
# 91     Hizdahr zo Loraq*       12  True  False  49     0.245
# 85                 Olly*       13  True  False  53     0.245
# 90   Myrcella Baratheon*       12  True  False  50     0.240
# 87        Balon Greyjoy*       12  True  False  52     0.231
# 80             The Waif*       13  True  False  58     0.224
# 95     Selyse Baratheon*       11  True  False  50     0.220
# 83         Rickon Stark*       13  True  False  59     0.220
# 107     Alton Lannister*        8  True  False  37     0.216
# 131                Styr*        6  True  False  29     0.207
# 93          Mace Tyrell*       12  True  False  60     0.200
# 135    Rickard Karstark*        5  True  False  25     0.200
# 81         Benjen Stark*       13  True  False  66     0.197
# 92           Tyene Sand*       12  True  False  63     0.190
# 122    Matthos Seaworth*        7  True  False  39     0.179
# 99           Lady Crane*       10  True  False  58     0.172
# 100     Kevan Lannister*       10  True  False  60     0.167
# 114       Doran Martell*        8  True  False  51     0.157
# 101       Randyll Tarly*       10  True  False  65     0.154
# 109    Three-Eyed Raven*        8  True  False  55     0.145
# 116             Wun Wun*        8  True  False  59     0.136
# 113          Obara Sand*        8  True  False  63     0.127
# 112        Nymeria Sand*        8  True  False  63     0.127
# 121         Brother Ray*        7  True  False  57     0.123
# 118      Razdal mo Eraz*        7  True  False  59     0.119
# 125      Othell Yarwyck*        6  True  False  53     0.113
# 136         Rattleshirt*        5  True  False  48     0.104
# 134           Khal Moro*        5  True  False  54     0.093
#
# [91 rows x 6 columns]

# %%
death_val = dead_people.groupby(['Ep'])['MinPerEp'].agg('sum')

# %%
# Season Lines found from https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,22],color='lightgrey',linewidth=0.5)
plt.bar(death_val.index,death_val.values)
plt.ylim(top=22)
plt.xlim([0,73])
plt.title('Significant Deaths per Episode')
plt.ylabel('Cumulative Deaths Value')
plt.xlabel('Episode')
plt.show()

# %%
# I don't think the Death Value here is reflective, because I 
# essentially make deaths N episodes in N times more shocking/valuable
# to register-- which is somewhat true but not so strict

# I mean currently the Red Wedding is half as intense as 
# Ned Stark's death. Which just isn't fair

# This is essentially punishing someone for being killed late in the season, and 
# rewarding someone for dying early.

# %%
# Trying a second metric that gives you 2 minutes of screen time per episode you survive:
dead_people['DeathValue2'] = round(
    (dead_people['Minutes']+2*dead_people['Ep'])
    /dead_people['Ep'],3)
dead_people.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#            Character  Minutes  Dead    8.3  Ep  MinPerEp  DeathValue2
# 10    Petyr Baelish*      119  True  False  67     1.776        3.776
# 12        Ned Stark*      100  True  False   6    16.667       18.667
# 17    Catelyn Stark*       83  True  False  19     4.368        6.368
# 18  Tywin Lannister*       78  True  False  30     2.600        4.600
# 19  Margaery Tyrell*       78  True  False  60     1.300        3.300

# %%
death_val2 = dead_people.groupby(['Ep'])['DeathValue2'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,30],color='lightgrey',linewidth=0.5)
plt.bar(death_val2.index,death_val2.values, label='DeathValue2', color='orange')
plt.ylim(top=25)
plt.xlim([0,73])
plt.title('Death Value per Episode')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.show()

# %%
ned_vis_execution = 6
ned_vis_score = 23

red_wedding = 19
red_wedding_score = 15

wilding_invasion = 29
wilding_score =14

stannis_myrcella = 50
stannis_score = 12.5

tyrell_death = 60
tyrell_score = 22

death_val2 = dead_people.groupby(['Ep'])['DeathValue2'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,30],color='lightgrey',linewidth=0.5)
plt.bar(death_val.index,death_val.values, label='DeathValue1')
plt.bar(death_val2.index,death_val2.values, label='DeathValue2')
plt.ylim(top=27)
plt.xlim([0,73])
plt.title('Death Value per Episode')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.text(ned_vis_execution-4,ned_vis_score+1.5, 'Ned Execution',fontsize=8)
plt.text(red_wedding-6,red_wedding_score+0.5, 'Red Wedding',fontsize=8)
plt.text(wilding_invasion-3,wilding_score+0.5, 'Wildling Invasion',fontsize=8)
plt.text(stannis_myrcella-3,stannis_score+0.5, 'Stannis',fontsize=8)
plt.text(tyrell_death-3,tyrell_score+1, 'RIP Tyrells',fontsize=8)
plt.show()

# %%
# Calling this the "Will Dilemma" because 
# Will is apparently the 2nd most important death in GoT because he is killed in the first
# episode after 6 minutes

# %%
# Found a Popularity Score: https://data.world/data-society/game-of-thrones 
# Essentially counted the number of links on the wiki page and normalized it 
# They consider people over .34 score as popular
# Adding to dataset

# %%
char_pd = pd.read_csv('got_data/character-predictions.csv')
pop_pd = char_pd[['name','popularity']]
pop_pd.head()
# Out:
#                    name  popularity
# 0  Viserys II Targaryen    0.605351
# 1           Walder Frey    0.896321
# 2          Addison Hill    0.267559
# 3           Aemma Arryn    0.183946
# 4        Sylva Santagar    0.043478

# %%
# Naming Mismatches:
kaggle_names = pop_pd.name.values
death_names = [dead_name[:-1] for dead_name in dead_people.Character.values]
for name in death_names:
    if name not in kaggle_names:
        name_mismatch_fix_dict[name]

# %%
name_mismatch_fix_dict = {
    'Ned Stark':1.0,
    'Ramsay Bolton':0.461538,
    'Olenna Tyrell':1.0,
    'Grand Maester Pycelle':0.638796,
    'Robert Baratheon':0.65,
    'Talisa':0.65,
    'Thoros of Myr':100,
    'Khal Drogo':0.558528,
    'Maester Luwin':0.351171,
    'Ros':0.1,
    'Maester Aemon':0.311037,
    'Locke':0.06,
    'Myranda':0.06,
    'The Waif':0.06,
    'Olly':0.401338,
    'Selyse Baratheon':0.397993,
    'Karl Tanner':0.06,
    'Lady Crane':0.473244,
    'Alton Lannister':0.26622,
    'Three-Eyed Raven':0.26622,
    'Wun Wun':0.26622,
    'Razdal mo Eraz':0.1137,
    'Brother Ray':0.1137,
    'Septa Mordane':0.12319,
    'Spice King':0.12319,
    'Dagmer Cleftjaw':0.12319,
    'Khal Moro':0.12319,
    'Rattleshirt':0.12319
}

# %%
pop_pd[pop_pd['name'] == 'Catelyn Stark']['popularity'] = 1.0
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
char_pd = pd.read_csv('got_data/character-predictions.csv')
pop_pd = char_pd[['name','popularity']]

name_mismatch_fix_dict = {
    'Ned Stark':1.0,
    'Ramsay Bolton':0.461538,
    'Olenna Tyrell':0.65,
    'Grand Maester Pycelle':0.638796,
    'Robert Baratheon':0.65,
    'Talisa':0.65,
    'Thoros of Myr':0.230769,
    'Khal Drogo':0.558528,
    'Maester Luwin':0.351171,
    'Ros':0.1,
    'Maester Aemon':0.311037,
    'Locke':0.06,
    'Myranda':0.06,
    'The Waif':0.06,
    'Olly':0.401338,
    'Selyse Baratheon':0.397993,
    'Karl Tanner':0.06,
    'Lady Crane':0.473244,
    'Alton Lannister':0.26622,
    'Three-Eyed Raven':0.26622,
    'Wun Wun':0.26622,
    'Razdal mo Eraz':0.1137,
    'Brother Ray':0.1137,
    'Septa Mordane':0.12319,
    'Spice King':0.12319,
    'Dagmer Cleftjaw':0.12319,
    'Khal Moro':0.12319,
    'Rattleshirt':0.12319
}

def get_importance_score(row):
    char_name = row['Character']
    if '*' in char_name:
        char_name = char_name[:-1]
        
    if char_name == 'Catelyn Stark':
        return(1.0)
    elif char_name == 'Lysa Arryn':
        return(0.473244)
    temp_pd = pop_pd[pop_pd.name==char_name]
    if temp_pd.shape[0] == 0:
        pop = name_mismatch_fix_dict[char_name]
    else:
        pop = temp_pd.popularity.values[0]
    
    return(pop)
  
# This only works for Dead People (currently)
dead_people['popularity'] = dead_people.apply (lambda row: get_importance_score(row), axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dead_people['DeathValue3'] = round(
    (dead_people['Minutes']+2*dead_people['Ep'])
    /dead_people['Ep']*dead_people['popularity'],3)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dead_people.sort_values('popularity', ascending=False)
# Out:
#                   Character  Minutes  Dead    8.3  Ep  MinPerEp  DeathValue2  \
# 10           Petyr Baelish*      119  True  False  67     1.776        3.776
# 22       Stannis Baratheon*       73  True  False  50     1.460        3.460
# 58         Renly Baratheon*       24  True  False  35     0.686        2.686
# 38         Barristan Selmy*       37  True  False  44     0.841        2.841
# 34        Tommen Baratheon*       43  True  False  60     0.717        2.717
# 23       Joffrey Baratheon*       70  True  False  22     3.182        5.182
# 12               Ned Stark*      100  True  False   6    16.667       18.667
# 20              Robb Stark*       77  True  False  19     4.053        6.053
# 19         Margaery Tyrell*       78  True  False  60     1.300        3.300
# 18         Tywin Lannister*       78  True  False  30     2.600        4.600
# 17           Catelyn Stark*       83  True  False  19     4.368        6.368
# 44            Roose Bolton*       30  True  False  52     0.577        2.577
# 74             Walder Frey*       16  True  False  60     0.267        2.267
# 100        Kevan Lannister*       10  True  False  60     0.167        2.167
# 93             Mace Tyrell*       12  True  False  60     0.200        2.200
# 49          Oberyn Martell*       29  True  False  28     1.036        3.036
# 87           Balon Greyjoy*       12  True  False  52     0.231        2.231
# 62            Mance Rayder*       21  True  False  41     0.512        2.512
# 41            Loras Tyrell*       32  True  False  60     0.533        2.533
# 43        Robert Baratheon*       31  True  False   7     4.429        6.429
# 42                  Talisa*       31  True  False  29     1.069        3.069
# 33           Olenna Tyrell*       44  True  False  63     0.698        2.698
# 39   Grand Maester Pycelle*       35  True  False  60     0.583        2.583
# 64       Viserys Targaryen*       21  True  False   6     3.500        5.500
# 101          Randyll Tarly*       10  True  False  65     0.154        2.154
# 63            Jeor Mormont*       21  True  False  14     1.500        3.500
# 90      Myrcella Baratheon*       12  True  False  50     0.240        2.240
# 53              Khal Drogo*       25  True  False  11     2.273        4.273
# 83            Rickon Stark*       13  True  False  59     0.220        2.220
# 114          Doran Martell*        8  True  False  51     0.157        2.157
# ..                      ...      ...   ...    ...  ..       ...          ...
# 105                Rakharo*        9  True  False  32     0.281        2.281
# 120                Craster*        7  True  False  24     0.292        2.292
# 124            Jory Cassel*        6  True  False   5     1.200        3.200
# 37            High Sparrow*       38  True  False  60     0.633        2.633
# 126                   Will*        6  True  False   1     6.000        8.000
# 115         Mirri Maz Duur*        8  True  False  11     0.727        2.727
# 113             Obara Sand*        8  True  False  63     0.127        2.127
# 131                   Styr*        6  True  False  29     0.207        2.207
# 92              Tyene Sand*       12  True  False  63     0.190        2.190
# 130             Spice King*        6  True  False  17     0.353        2.353
# 127          Septa Mordane*        6  True  False   8     0.750        2.750
# 136            Rattleshirt*        5  True  False  48     0.104        2.104
# 134              Khal Moro*        5  True  False  54     0.093        2.093
# 133        Dagmer Cleftjaw*        5  True  False  20     0.250        2.250
# 88                   Pypar*       12  True  False  29     0.414        2.414
# 121            Brother Ray*        7  True  False  57     0.123        2.123
# 118         Razdal mo Eraz*        7  True  False  59     0.119        2.119
# 86                  Doreah*       13  True  False  40     0.325        2.325
# 60                     Ros*       22  True  False  17     1.294        3.294
# 103                  Orell*        9  True  False  19     0.474        2.474
# 122       Matthos Seaworth*        7  True  False  39     0.179        2.179
# 128               Polliver*        6  True  False  21     0.286        2.286
# 129      Kraznys mo Nakloz*        6  True  False  14     0.429        2.429
# 82                    Rast*       13  True  False  26     0.500        2.500
# 137                  Qotho*        5  True  False   9     0.556        2.556
# 125         Othell Yarwyck*        6  True  False  53     0.113        2.113
# 78                 Myranda*       13  True  False  50     0.260        2.260
# 77                   Locke*       13  True  False  26     0.500        2.500
# 80                The Waif*       13  True  False  58     0.224        2.224
# 96             Karl Tanner*       11  True  False  26     0.423        2.423
#
#      popularity  DeathValue3
# 10     1.000000        3.776
# 22     1.000000        3.460
# 58     1.000000        2.686
# 38     1.000000        2.841
# 34     1.000000        2.717
# 23     1.000000        5.182
# 12     1.000000       18.667
# 20     1.000000        6.053
# 19     1.000000        3.300
# 18     1.000000        4.600
# 17     1.000000        6.368
# 44     0.979933        2.525
# 74     0.896321        2.032
# 100    0.869565        1.884
# 93     0.856187        1.884
# 49     0.772575        2.345
# 87     0.739130        1.649
# 62     0.709030        1.781
# 41     0.665552        1.686
# 43     0.650000        4.179
# 42     0.650000        1.995
# 33     0.650000        1.754
# 39     0.638796        1.650
# 64     0.622074        3.421
# 101    0.618729        1.333
# 63     0.618729        2.166
# 90     0.561873        1.259
# 53     0.558528        2.386
# 83     0.551839        1.225
# 114    0.498328        1.075
# ..          ...          ...
# 105    0.183946        0.420
# 120    0.170569        0.391
# 124    0.170569        0.546
# 37     0.167224        0.440
# 126    0.163880        1.311
# 115    0.143813        0.392
# 113    0.140468        0.299
# 131    0.140468        0.310
# 92     0.137124        0.300
# 130    0.123190        0.290
# 127    0.123190        0.339
# 136    0.123190        0.259
# 134    0.123190        0.258
# 133    0.123190        0.277
# 88     0.113712        0.274
# 121    0.113700        0.241
# 118    0.113700        0.241
# 86     0.110368        0.257
# 60     0.100000        0.329
# 103    0.080268        0.199
# 122    0.076923        0.168
# 128    0.076923        0.176
# 129    0.076923        0.187
# 82     0.066890        0.167
# 137    0.063545        0.162
# 125    0.063545        0.134
# 78     0.060000        0.136
# 77     0.060000        0.150
# 80     0.060000        0.133
# 96     0.060000        0.145
#
# [91 rows x 9 columns]

# %%
ned_vis_execution = 6
ned_vis_score = 23

red_wedding = 19
red_wedding_score = 15

wilding_invasion = 29
wilding_score =14

stannis_myrcella = 50
stannis_score = 12.5

tyrell_death = 60
tyrell_score = 22

death_val3 = dead_people.groupby(['Ep'])['DeathValue3'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,30],color='lightgrey',linewidth=0.5)
plt.bar(death_val3.index,death_val3.values, label='DeathValue3',color='green')
plt.ylim(top=27)
plt.xlim([0,73])
plt.title('Death Value per Episode')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.text(ned_vis_execution-4,ned_vis_score+1.5, 'Ned Execution',fontsize=8)
plt.text(red_wedding-6,red_wedding_score+0.5, 'Red Wedding',fontsize=8)
plt.text(wilding_invasion-3,wilding_score+0.5, 'Wildling Invasion',fontsize=8)
plt.text(stannis_myrcella-3,stannis_score+0.5, 'Stannis',fontsize=8)
plt.text(tyrell_death-3,tyrell_score+1, 'RIP Tyrells',fontsize=8)
plt.show()

# %%
# This looks even better -- BUT there is now a major confounding variable added to this whole mess:
# Book vs. Movie
# Characters that play larger roles in the Book no longer exist (Rickard Stark), and characters in the show 
# that matter greatly (Ramsay Bolton) and not as important in the book... Let's look at how this popularity score
# stacks up against screentime:

# %%
def get_book_popularity(row):
    
    char_name = row['Character']
    if '*' in char_name:
        char_name = char_name[:-1]
        
        
        
    # Some names are just mislabelled... nobody's perfect!
    if char_name == 'Catelyn Stark':
        return(1.0)

    temp_pd = pop_pd[pop_pd.name==char_name]
    
    # If not in dataset
    if temp_pd.shape[0] == 0:
        try:
            pop = name_mismatch_fix_dict[char_name]
        except KeyError:
            print(name)
            pop = 0.0
            
    else:
        pop = temp_pd.popularity.values[0]
    
    return(pop)

got_data['book_popularity'] = got_data.apply (lambda row: get_book_popularity(row), axis=1)
# Out:
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister
# Tytos Lannister

# %%
got_data['movie_popularity'] = got_data['Minutes']/got_data['Ep']

# %%
x = got_data.Minutes.values + 0
normal_screentime = norm1 = x / np.linalg.norm(x)

plt.scatter(got_data.book_popularity.values,got_data.Minutes.values, alpha=0.7)
plt.xlabel('Book Popularity')
plt.ylabel('Show Screentime')
plt.title('GoT Book vs. Show Popularity')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.hist(got_data.book_popularity.values, bins=25)
ax1.set_title('Book Popularity')
ax2.hist(got_data.Minutes.values, bins=25)
ax2.set_title('Show Screentime')
plt.show()

# %%
got_data['movie_popularity'] = normal_screentime

got_data['bigger_in_book'] = got_data['book_popularity'] - got_data['movie_popularity']

# %%
got_data.sort_values('bigger_in_book').head(10)
# Out:
#               Character  Minutes   Dead    8.3  book_popularity  \
# 126               Will*        6   True  False          0.16388
# 14     Brienne of Tarth       98  False   True          0.00000
# 71          Lysa Arryn*       17   True  False          0.00000
# 40         Yara Greyjoy       32  False  False          0.00000
# 84         Septa Unella       13  False  False          0.00000
# 94          Robin Arryn       11  False  False          0.00000
# 104  Archmaester Ebrose        9  False  False          0.00000
# 111    Yezzan zo Qaggaz        8  False  False          0.00000
# 106              Olyvar        8  False  False          0.00000
# 108      The Night King        8  False   True          0.00000
#
#      movie_popularity  bigger_in_book  Ep
# 126          0.248804       -0.084924   1
# 14           0.060654       -0.060654  67
# 71           0.026109       -0.026109  27
# 40           0.019805       -0.019805  67
# 84           0.008046       -0.008046  67
# 94           0.006808       -0.006808  67
# 104          0.005570       -0.005570  67
# 111          0.004951       -0.004951  67
# 106          0.004951       -0.004951  67
# 108          0.004951       -0.004951  67

# %%
got_data.sort_values('bigger_in_book',ascending=False).head(25)
# Out:
#               Character  Minutes   Dead    8.3  book_popularity  \
# 58     Renly Baratheon*       24   True  False         1.000000
# 34    Tommen Baratheon*       43   True  False         1.000000
# 38     Barristan Selmy*       37   True  False         1.000000
# 44        Roose Bolton*       30   True  False         0.979933
# 19     Margaery Tyrell*       78   True  False         1.000000
# 22   Stannis Baratheon*       73   True  False         1.000000
# 13           Bran Stark       99  False   True         1.000000
# 10       Petyr Baelish*      119   True  False         1.000000
# 9         Theon Greyjoy      136  False   True         1.000000
# 11       Davos Seaworth      110  False   True         0.969900
# 18     Tywin Lannister*       78   True  False         1.000000
# 74         Walder Frey*       16   True  False         0.896321
# 7         Samwell Tarly      144  False   True         0.969900
# 6       Jaime Lannister      199  False   True         1.000000
# 23   Joffrey Baratheon*       70   True  False         1.000000
# 100    Kevan Lannister*       10   True  False         0.869565
# 5            Arya Stark      224  False   True         1.000000
# 4      Cersei Lannister      236  False  False         1.000000
# 3           Sansa Stark      239  False   True         1.000000
# 93         Mace Tyrell*       12   True  False         0.856187
# 16                Varys       94  False   True         0.899666
# 20          Robb Stark*       77   True  False         1.000000
# 2    Daenerys Targaryen      276  False   True         1.000000
# 57       Gregor Clegane       24  False  False         0.836120
# 17       Catelyn Stark*       83   True  False         1.000000
#
#      movie_popularity  bigger_in_book  Ep
# 58           0.028435        0.971565  35
# 34           0.029718        0.970282  60
# 38           0.034870        0.965130  44
# 44           0.023923        0.956010  52
# 19           0.053908        0.946092  60
# 22           0.060542        0.939458  50
# 13           0.061273        0.938727  67
# 10           0.073651        0.926349  67
# 9            0.084172        0.915828  67
# 11           0.068081        0.901819  67
# 18           0.107815        0.892185  30
# 74           0.011058        0.885263  60
# 7            0.089124        0.880776  67
# 6            0.123164        0.876836  67
# 23           0.131942        0.868058  22
# 100          0.006911        0.862654  60
# 5            0.138637        0.861363  67
# 4            0.146064        0.853936  67
# 3            0.147921        0.852079  67
# 93           0.008293        0.847894  60
# 16           0.058178        0.841488  67
# 20           0.168052        0.831948  19
# 2            0.170821        0.829179  67
# 57           0.014854        0.821266  67
# 17           0.181147        0.818853  19

# %%
got_data['Ep'] = got_data.apply (lambda row: death_episode(row), axis=1)

# %%
got_data['DeathValue'] = round(
    (got_data['Minutes']+2*got_data['Ep'])
    /got_data['Ep']*got_data['book_popularity'],3)
got_data.head()
# Out:
#             Character  Minutes   Dead    8.3  book_popularity  \
# 0            Jon Snow      338  False   True              1.0
# 1    Tyrion Lannister      337  False   True              1.0
# 2  Daenerys Targaryen      276  False   True              1.0
# 3         Sansa Stark      239  False   True              1.0
# 4    Cersei Lannister      236  False  False              1.0
#
#    movie_popularity  bigger_in_book  Ep  DeathValue
# 0          0.209193        0.790807 NaN         NaN
# 1          0.208574        0.791426 NaN         NaN
# 2          0.170821        0.829179 NaN         NaN
# 3          0.147921        0.852079 NaN         NaN
# 4          0.146064        0.853936 NaN         NaN

# %%
def winterfell_potential(row):
    if row['8.3']:
        ltv = round((row['Minutes']+(144/70)+2*70)/70*row['book_popularity'],3)
    else:
        ltv = None
    return(ltv)
got_data['8.3_value'] = got_data.apply (lambda row: winterfell_potential(row), axis=1)
got_data[got_data['8.3_value'] > 0][['Character','8.3_value']]
# Out:
#               Character  8.3_value
# 0              Jon Snow      6.858
# 1      Tyrion Lannister      6.844
# 2    Daenerys Targaryen      5.972
# 3           Sansa Stark      5.444
# 5            Arya Stark      5.229
# 6       Jaime Lannister      4.872
# 7         Samwell Tarly      3.964
# 8         Jorah Mormont      2.942
# 9         Theon Greyjoy      3.972
# 11       Davos Seaworth      3.492
# 13           Bran Stark      3.444
# 15       Sandor Clegane      2.356
# 16                Varys      3.034
# 24           Melisandre      2.249
# 26            Missandei      0.507
# 27                Gilly      0.810
# 28              Tormund      0.603
# 32        Podrick Payne      0.778
# 35            Grey Worm      0.371
# 36               Gendry      1.133
# 47      Eddison Tollett      0.245
# 54     Beric Dondarrion      1.038
# 132      Lyanna Mormont      0.119

# %%
sum(got_data[got_data['8.3_value'] > 0]['8.3_value'].values)
# Out:
# 66.276

# %%
ned_vis_execution = 6
ned_vis_score = 21

red_wedding = 19
red_wedding_score = 13

wilding_invasion = 29
wilding_score =8

stannis_myrcella = 50
stannis_score = 8

tyrell_death = 60
tyrell_score = 17

winterfell_deaths = ['Eddison Tollett','Beric Dondarrion','Lyanna Mormont','Theon Greyjoy','Melisandre','Jorah Mormont']
winterfell_val = 0
for person in winterfell_deaths:
    winterfell_val += got_data[got_data['Character'] == person]['8.3_value'].values[0]
    
death_val3 = dead_people.groupby(['Ep'])['DeathValue3'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,30],color='lightgrey',linewidth=0.5)
plt.bar(death_val3.index,death_val3.values, label='DeathValue3',color='green')
plt.bar([70],[winterfell_val])
plt.ylim(top=27)
plt.xlim([0,73])
plt.title('Death Value per Episode')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.text(ned_vis_execution-4,ned_vis_score+1.5, 'Ned Execution',fontsize=8)
plt.text(red_wedding-6,red_wedding_score+0.5, 'Red Wedding',fontsize=8)
plt.text(wilding_invasion-3,wilding_score+0.5, 'Wildling Invasion',fontsize=8)
plt.text(stannis_myrcella-3,stannis_score+0.5, 'Stannis',fontsize=8)
plt.text(tyrell_death-3,tyrell_score+1, 'RIP Tyrells',fontsize=8)
plt.show()

# %%
# What if....

# %%
ned_vis_execution = 6
ned_vis_score = 21

red_wedding = 19
red_wedding_score = 13

wilding_invasion = 29
wilding_score =8

stannis_myrcella = 50
stannis_score = 8

tyrell_death = 60
tyrell_score = 17

winterfell_val = sum(got_data[got_data['8.3_value'] > 0]['8.3_value'].values)
    
death_val3 = dead_people.groupby(['Ep'])['DeathValue3'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,100],color='lightgrey',linewidth=0.5)
plt.bar(death_val3.index,death_val3.values, label='DeathValue3',color='green')
plt.bar([70],[winterfell_val])
plt.ylim(top=71)
plt.xlim([0,73])
plt.title('8.3: What if Everyone Died?')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.text(ned_vis_execution-4,ned_vis_score+1.5, 'Ned Execution',fontsize=8)
plt.text(red_wedding-6,red_wedding_score+0.5, 'Red Wedding',fontsize=8)
plt.text(wilding_invasion-3,wilding_score+0.5, 'Wildling Invasion',fontsize=8)
plt.text(stannis_myrcella-3,stannis_score+0.5, 'Stannis',fontsize=8)
plt.text(tyrell_death-3,tyrell_score+1, 'RIP Tyrells',fontsize=8)
plt.text(70-3,winterfell_val+2,str(winterfell_val), fontsize=8)
plt.show()

# %%
ned_vis_execution = 6
ned_vis_score = 21

red_wedding = 19
red_wedding_score = 13

wilding_invasion = 29
wilding_score =8

stannis_myrcella = 50
stannis_score = 8

tyrell_death = 60
tyrell_score = 17

winterfell_val = sum(got_data[got_data['8.3_value'] > 0]['8.3_value'].values)
    
death_val3 = dead_people.groupby(['Ep'])['DeathValue3'].agg('sum')
for eps in [10,20,30,40,50,60,67]:
    plt.plot([eps,eps],[0,100],color='lightgrey',linewidth=0.5)
plt.bar(death_val3.index,death_val3.values, label='DeathValue3',color='green')
plt.bar([70],[winterfell_val])
plt.ylim(top=71)
plt.xlim([0,73])
plt.title('8.3: What if Everyone Died?')
plt.ylabel('Cumulative Death Value')
plt.xlabel('Episode')
plt.text(ned_vis_execution-4,ned_vis_score+1.5, 'Ned Execution',fontsize=8)
plt.text(red_wedding-6,red_wedding_score+0.5, 'Red Wedding',fontsize=8)
plt.text(wilding_invasion-3,wilding_score+0.5, 'Wildling Invasion',fontsize=8)
plt.text(stannis_myrcella-3,stannis_score+0.5, 'Stannis',fontsize=8)
plt.text(tyrell_death-3,tyrell_score+1, 'RIP Tyrells',fontsize=8)
plt.text(70-3,winterfell_val+2,str(winterfell_val), fontsize=8)
plt.show()
# Out:
# nan

# %% [markdown]
# ## Lord of the Rings

# %%
# I want to add Star Wars Original Trilogy and 
# Lord of the Rings Directors Cut to the above graph
# Screentime of LoTR characters from https://www.imdb.com/list/ls036259945/
# (but actually https://www.jetpunk.com/quizzes/lord-of-the-rings-characters-by-screen-time)
# deaths were verified https://lotr.fandom.com/wiki/List_of_deaths_in_the_Lord_of_the_Rings_films
lotr_screen_time = {
    'Frodo Baggins':121,
    'Samwise Gamgee':78,
    'Aragorn':74,
    'Gandalf':71,
    'Pippin Took':50,
    'Merry Brandybuck':41,
    'Gollum':34,
    'Legolas':31,
    'Gimli':31,
    'Théoden':24, #dead
    'Boromir':20, #dead
    'Éowyn':18,
    'Arwen':15,
    'Bilbo Baggins': 13,
    'Elrond':12,
    'Faramir':12,
    'Treebeard':10,
    'Saruman':9, #dead
    'Galadriel':8,
    'Éomer':8,
    'The Witch King':7, #dead
    'Denethor':6, #dead
    'Wormtongue':5, #dead
    'Gamling':4,
    'Sauron':4 #dead
}

fellowship = 178 #https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Fellowship_of_the_Ring
towers = 179 # https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Two_Towers
king = 200 # https://en.wikipedia.org/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King
lotr_run_time = fellowship+towers+king
print('LOTR Run Time:',lotr_run_time)
lotr_ep_length = np.floor(lotr_run_time/73)
print('LOTR "Episode" Length:',lotr_ep_length)


# Now I'm going to have to watch LOTR to find the timestamps of all these deaths (oh no!)
# Out:
# LOTR Run Time: 557
# LOTR "Episode" Length: 7.0

# %%
# https://www.digitalspy.com/movies/a861558/movie-extended-version-dvd-lord-of-the-rings-suicide-squad/


# Things that are left out of regular for extended are almost all character development, 
# but pertaining to death value:
    # Boromir + Faramir have a flashback
    # Witch King + Sauron get more screen time
    # Faramir's romance gets more screen time
    # Sauromans + Wormtounge's last scenes + deaths are in extension
